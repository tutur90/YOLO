# %%
import cv2
import numpy as np
from ultralytics import YOLO


# defining function for creating a writer (for mp4 videos)
def create_video_writer(video_cap, output_filename):
    # grab the width, height, and fps of the frames in the video stream.
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    # initialize the FourCC and a video writer object
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    writer = cv2.VideoWriter(output_filename, fourcc, fps,
                             (frame_width, frame_height))
    return writer

# %%
import cv2
import numpy as np
from ultralytics import YOLO


from collections import defaultdict


# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# Load the YOLOv8 model
model = YOLO('yolov9c.pt')

# Open the video file
video_path = "DJI_0015.MOV"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])
# Store the class history
cls_history = defaultdict(lambda: [])

frame_number = 0

writer = create_video_writer(cap, f"{video_path}_annoted.mp4")

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        frame_number += 1
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        # detect only classes=[2,5,7], car, bus, truck
        results = model.track(frame, persist=True, conf=0.002, classes=[0, 2, 5, 7])
        

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        # Get the boxes and track IDs
        
        if results[0].boxes.id is not None:
        
            boxes = results[0].boxes.xywh.cpu()
            clss = results[0].boxes.cls
            track_ids = results[0].boxes.id.int().cpu().tolist()


            # Plot the tracks
            for box, track_id, cls in zip(boxes, track_ids, clss):
                x, y, w, h = box
                track = track_history[track_id]
                ch = cls_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                ch.append((classNames[int(cls)], frame_number))
                # class name
                # print("Class name -->", classNames[int(cls)])

                # Draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(annotated_frame, [points], isClosed=False, color=(255, 255, 0), thickness=2)
        writer.write(annotated_frame)
        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", cv2.resize(annotated_frame, (1920, 1080)))

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 352x640 72 persons, 5 cars, 15 trucks, 1327.4ms
# Speed: 6.1ms preprocess, 1327.4ms inference, 479.6ms postprocess per image at shape (1, 3, 352, 640)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/arthur/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# 0: 352x640 83 persons, 3 cars, 17 trucks, 1237.6ms
# Speed: 21.4ms preprocess, 1237.6ms inference, 5.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 98 persons, 3 cars, 12 trucks, 350.2ms
# Speed: 1.8ms preprocess, 350.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 90 persons, 4 cars, 13 trucks, 337.1ms
# Speed: 10.0ms preprocess, 337.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 85 persons, 4 cars, 14 trucks, 310.5ms
# Speed: 1.8ms preprocess, 310.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 86 persons, 5 cars, 13 trucks, 283.2ms
# Speed: 1.7ms preprocess, 283.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 85 persons, 6 cars, 14 trucks, 298.3ms
# Speed: 1.7ms preprocess, 298.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 86 persons, 7 cars, 14 trucks, 333.5ms
# Speed: 1.9ms preprocess, 333.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 83 persons, 9 cars, 14 trucks, 309.2ms
# Speed: 2.1ms preprocess, 309.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 68 persons, 13 cars, 15 trucks, 300.5ms
# Speed: 1.9ms preprocess, 300.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 74 persons, 10 cars, 11 trucks, 329.8ms
# Speed: 1.9ms preprocess, 329.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 77 persons, 13 cars, 17 trucks, 365.1ms
# Speed: 26.7ms preprocess, 365.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 67 persons, 10 cars, 17 trucks, 278.8ms
# Speed: 1.9ms preprocess, 278.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 67 persons, 12 cars, 15 trucks, 366.6ms
# Speed: 2.5ms preprocess, 366.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 truck, 329.2ms
# Speed: 1.6ms preprocess, 329.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]]
#
# 0: 352x640 1 truck, 298.5ms
# Speed: 1.9ms preprocess, 298.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]]
#
# 0: 352x640 1 truck, 310.6ms
# Speed: 1.7ms preprocess, 310.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]]
#
# 0: 352x640 1 truck, 244.1ms
# Speed: 2.3ms preprocess, 244.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]]
#
# 0: 352x640 1 truck, 311.5ms
# Speed: 2.2ms preprocess, 311.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]]
#
# 0: 352x640 1 truck, 272.4ms
# Speed: 1.9ms preprocess, 272.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]]
#
# 0: 352x640 1 truck, 299.8ms
# Speed: 2.0ms preprocess, 299.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]]
#
# 0: 352x640 1 truck, 320.7ms
# Speed: 1.9ms preprocess, 320.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]]
#
# 0: 352x640 1 truck, 273.4ms
# Speed: 2.4ms preprocess, 273.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]]
#
# 0: 352x640 1 truck, 284.2ms
# Speed: 2.1ms preprocess, 284.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]]
#
# 0: 352x640 1 truck, 312.2ms
# Speed: 1.7ms preprocess, 312.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]]
#
# 0: 352x640 2 trucks, 272.3ms
# Speed: 1.9ms preprocess, 272.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]]
# points --> [[[3831  433]]]
#
# 0: 352x640 2 trucks, 373.0ms
# Speed: 2.3ms preprocess, 373.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]]
#
# 0: 352x640 2 trucks, 334.3ms
# Speed: 3.0ms preprocess, 334.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]]
#
# 0: 352x640 2 trucks, 321.2ms
# Speed: 2.0ms preprocess, 321.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]]
#
# 0: 352x640 2 trucks, 272.4ms
# Speed: 1.8ms preprocess, 272.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]]
#
# 0: 352x640 2 trucks, 405.6ms
# Speed: 2.0ms preprocess, 405.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]]
#
# 0: 352x640 2 trucks, 324.0ms
# Speed: 1.7ms preprocess, 324.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]]
#
# 0: 352x640 2 trucks, 242.0ms
# Speed: 2.6ms preprocess, 242.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 278.7ms
# Speed: 1.8ms preprocess, 278.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 285.3ms
# Speed: 2.0ms preprocess, 285.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 297.7ms
# Speed: 2.1ms preprocess, 297.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]]
#
# 0: 352x640 2 trucks, 325.4ms
# Speed: 1.9ms preprocess, 325.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]]
#
# 0: 352x640 2 trucks, 332.1ms
# Speed: 2.4ms preprocess, 332.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]]
#
# 0: 352x640 2 trucks, 283.5ms
# Speed: 1.8ms preprocess, 283.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]]
#
# 0: 352x640 2 trucks, 337.7ms
# Speed: 1.8ms preprocess, 337.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]]
#
# 0: 352x640 2 trucks, 290.8ms
# Speed: 1.7ms preprocess, 290.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]]
#
# 0: 352x640 2 trucks, 277.3ms
# Speed: 1.9ms preprocess, 277.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]]
#
# 0: 352x640 2 trucks, 320.2ms
# Speed: 2.0ms preprocess, 320.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]]
#
# 0: 352x640 2 trucks, 289.7ms
# Speed: 1.9ms preprocess, 289.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]]
#
# 0: 352x640 2 trucks, 343.6ms
# Speed: 1.8ms preprocess, 343.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 262.4ms
# Speed: 2.7ms preprocess, 262.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 357.1ms
# Speed: 1.9ms preprocess, 357.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 312.3ms
# Speed: 1.8ms preprocess, 312.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]]
#
# 0: 352x640 2 trucks, 245.5ms
# Speed: 1.7ms preprocess, 245.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]]
#
# 0: 352x640 2 trucks, 352.5ms
# Speed: 2.1ms preprocess, 352.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]]
#
# 0: 352x640 2 trucks, 264.8ms
# Speed: 2.4ms preprocess, 264.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]]
#
# 0: 352x640 2 trucks, 265.9ms
# Speed: 2.2ms preprocess, 265.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]]
#
# 0: 352x640 2 trucks, 298.5ms
# Speed: 2.1ms preprocess, 298.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]]
#
# 0: 352x640 2 trucks, 313.4ms
# Speed: 2.2ms preprocess, 313.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]]
#
# 0: 352x640 2 trucks, 299.7ms
# Speed: 1.9ms preprocess, 299.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]]
#
# 0: 352x640 2 trucks, 299.4ms
# Speed: 2.8ms preprocess, 299.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]]
#
# 0: 352x640 2 trucks, 309.1ms
# Speed: 1.7ms preprocess, 309.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]]
#
# 0: 352x640 2 trucks, 368.2ms
# Speed: 7.5ms preprocess, 368.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]]
#
# 0: 352x640 2 trucks, 295.4ms
# Speed: 1.9ms preprocess, 295.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]]
#
# 0: 352x640 2 trucks, 306.4ms
# Speed: 2.7ms preprocess, 306.4ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]]
#
# 0: 352x640 2 trucks, 348.2ms
# Speed: 2.8ms preprocess, 348.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]]
#
# 0: 352x640 2 trucks, 336.4ms
# Speed: 10.7ms preprocess, 336.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]]
#
# 0: 352x640 2 trucks, 337.1ms
# Speed: 2.8ms preprocess, 337.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]]
#
# 0: 352x640 2 trucks, 335.1ms
# Speed: 2.2ms preprocess, 335.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]]
#
# 0: 352x640 2 trucks, 287.7ms
# Speed: 2.1ms preprocess, 287.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]]
#
# 0: 352x640 2 trucks, 414.5ms
# Speed: 1.7ms preprocess, 414.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]]
#
# 0: 352x640 2 trucks, 347.2ms
# Speed: 2.9ms preprocess, 347.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]
#
#  [[754 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]]
#
# 0: 352x640 2 trucks, 377.5ms
# Speed: 4.1ms preprocess, 377.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]
#
#  [[754 372]]
#
#  [[757 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3834  432]]]
#
# 0: 352x640 2 trucks, 404.5ms
# Speed: 5.4ms preprocess, 404.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]
#
#  [[754 372]]
#
#  [[757 372]]
#
#  [[759 372]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]]
#
# 0: 352x640 2 trucks, 362.0ms
# ...
#
#  [[766 374]]
#
#  [[769 376]]
#
#  [[771 375]]
#
#  [[772 375]]
#
#  [[776 375]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3833  429]]
#
#  [[3834  427]]
#
#  [[3834  426]]
#
#  [[3834  426]]
#
#  [[3833  426]]]
#
# 0: 352x640 2 trucks, 350.1ms
# Speed: 7.1ms preprocess, 350.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]
#
#  [[754 372]]
#
#  [[757 372]]
#
#  [[759 372]]
#
#  [[762 373]]
#
#  [[764 373]]
#
#  [[766 374]]
#
#  [[769 376]]
#
#  [[771 375]]
#
#  [[772 375]]
#
#  [[776 375]]
#
#  [[779 375]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3833  429]]
#
#  [[3834  427]]
#
#  [[3834  426]]
#
#  [[3834  426]]
#
#  [[3833  426]]
#
#  [[3833  426]]]
#
# 0: 352x640 2 trucks, 326.3ms
# Speed: 1.9ms preprocess, 326.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# points --> [[[668 394]]
#
#  [[669 383]]
#
#  [[669 375]]
#
#  [[669 375]]
#
#  [[671 379]]
#
#  [[666 378]]
#
#  [[661 376]]
#
#  [[665 374]]
#
#  [[665 373]]
#
#  [[672 373]]
#
#  [[676 376]]
#
#  [[679 378]]
#
#  [[681 377]]
#
#  [[682 377]]
#
#  [[684 381]]
#
#  [[685 381]]
#
#  [[684 379]]
#
#  [[687 378]]
#
#  [[690 378]]
#
#  [[691 380]]
#
#  [[693 380]]
#
#  [[695 382]]
#
#  [[696 378]]
#
#  [[698 376]]
#
#  [[702 377]]
#
#  [[703 376]]
#
#  [[706 378]]
#
#  [[708 375]]
#
#  [[711 376]]
#
#  [[712 376]]
#
#  [[715 378]]
#
#  [[716 376]]
#
#  [[718 375]]
#
#  [[719 374]]
#
#  [[720 373]]
#
#  [[721 372]]
#
#  [[722 373]]
#
#  [[724 372]]
#
#  [[726 371]]
#
#  [[728 371]]
#
#  [[731 371]]
#
#  [[733 370]]
#
#  [[736 370]]
#
#  [[738 370]]
#
#  [[740 369]]
#
#  [[742 370]]
#
#  [[743 371]]
#
#  [[746 371]]
#
#  [[746 370]]
#
#  [[748 371]]
#
#  [[751 372]]
#
#  [[751 371]]
#
#  [[754 372]]
#
#  [[757 372]]
#
#  [[759 372]]
#
#  [[762 373]]
#
#  [[764 373]]
#
#  [[766 374]]
#
#  [[769 376]]
#
#  [[771 375]]
#
#  [[772 375]]
#
#  [[776 375]]
#
#  [[779 375]]
#
#  [[782 376]]]
# points --> [[[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  433]]
#
#  [[3831  429]]
#
#  [[3831  430]]
#
#  [[3831  430]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3831  434]]
#
#  [[3831  433]]
#
#  [[3831  432]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  431]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  432]]
#
#  [[3831  433]]
#
#  [[3832  433]]
#
#  [[3832  434]]
#
#  [[3832  433]]
#
#  [[3833  433]]
#
#  [[3833  433]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3833  431]]
#
#  [[3834  430]]
#
#  [[3834  430]]
#
#  [[3833  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  432]]
#
#  [[3834  431]]
#
#  [[3833  429]]
#
#  [[3834  427]]
#
#  [[3834  426]]
#
#  [[3834  426]]
#
#  [[3833  426]]
#
#  [[3833  426]]
#
#  [[3833  426]]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 47
#      44 frame_number += 1
#      45 # Run YOLOv8 tracking on the frame, persisting tracks between frames
#      46 # detect only classes=[2,5,7], car, bus, truck
# ---> 47 results = model.track(frame, persist=True, conf=0.002, classes=[0, 2, 5, 7])
#      50 # Visualize the results on the frame
#      51 annotated_frame = results[0].plot()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:492, in Model.track(self, source, stream, persist, **kwargs)
#     490 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     491 kwargs["mode"] = "track"
# --> 492 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/head.py:47, in Detect.forward(self, x)
#      45 """Concatenates and returns predicted bounding boxes and class probabilities."""
#      46 for i in range(self.nl):
# ---> 47     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      48 if self.training:  # Training path
#      49     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
import cv2
import numpy as np
from ultralytics import YOLO


from collections import defaultdict


# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# Load the YOLOv8 model
model = YOLO('yolov9c.pt')

# Open the video file
video_path = "DJI_0015.MOV"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])
# Store the class history
cls_history = defaultdict(lambda: [])

frame_number = 0

writer = create_video_writer(cap, f"{video_path}_annoted.mp4")

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        frame_number += 1
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        # detect only classes=[2,5,7], car, bus, truck
        results = model.predict(frame, conf=0.04, classes=[0, 2, 5, 7])
        

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        # Get the boxes and track IDs


        writer.write(annotated_frame)
        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", cv2.resize(annotated_frame, (1920, 1080)))

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 352x640 7 persons, 4 trucks, 373.3ms
# Speed: 2.6ms preprocess, 373.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 car, 4 trucks, 300.7ms
# Speed: 2.1ms preprocess, 300.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 4 trucks, 324.5ms
# Speed: 2.8ms preprocess, 324.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 14 persons, 1 car, 4 trucks, 299.5ms
# Speed: 2.5ms preprocess, 299.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 2 cars, 3 trucks, 328.7ms
# Speed: 3.8ms preprocess, 328.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 2 cars, 3 trucks, 401.0ms
# Speed: 2.4ms preprocess, 401.0ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 2 cars, 3 trucks, 365.5ms
# Speed: 3.0ms preprocess, 365.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 2 cars, 3 trucks, 350.0ms
# Speed: 3.3ms preprocess, 350.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 2 cars, 4 trucks, 385.8ms
# Speed: 5.2ms preprocess, 385.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 3 cars, 3 trucks, 292.3ms
# Speed: 3.5ms preprocess, 292.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 4 cars, 3 trucks, 407.2ms
# Speed: 3.5ms preprocess, 407.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 5 cars, 3 trucks, 374.4ms
# Speed: 2.5ms preprocess, 374.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 390.2ms
# Speed: 42.6ms preprocess, 390.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 2 cars, 3 trucks, 302.3ms
# Speed: 3.9ms preprocess, 302.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 2 cars, 3 trucks, 357.9ms
# Speed: 5.3ms preprocess, 357.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 car, 3 trucks, 343.6ms
# Speed: 4.2ms preprocess, 343.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 3 cars, 3 trucks, 373.8ms
# Speed: 2.7ms preprocess, 373.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 3 cars, 4 trucks, 404.5ms
# Speed: 1.9ms preprocess, 404.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 2 cars, 3 trucks, 297.2ms
# Speed: 2.7ms preprocess, 297.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 2 cars, 3 trucks, 320.8ms
# Speed: 3.2ms preprocess, 320.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 3 cars, 3 trucks, 342.1ms
# Speed: 3.1ms preprocess, 342.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 3 trucks, 321.2ms
# Speed: 2.4ms preprocess, 321.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 2 trucks, 415.0ms
# Speed: 3.4ms preprocess, 415.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 2 trucks, 355.3ms
# Speed: 2.9ms preprocess, 355.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 3 trucks, 323.9ms
# Speed: 2.2ms preprocess, 323.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 4 trucks, 336.1ms
# Speed: 3.0ms preprocess, 336.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 car, 4 trucks, 347.8ms
# Speed: 3.6ms preprocess, 347.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 car, 4 trucks, 356.0ms
# Speed: 2.8ms preprocess, 356.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 4 trucks, 347.0ms
# Speed: 2.7ms preprocess, 347.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 5 trucks, 284.0ms
# Speed: 2.2ms preprocess, 284.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 5 trucks, 330.2ms
# Speed: 2.2ms preprocess, 330.2ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 5 trucks, 454.6ms
# Speed: 2.8ms preprocess, 454.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 5 trucks, 313.9ms
# Speed: 2.3ms preprocess, 313.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 2 cars, 4 trucks, 307.5ms
# Speed: 2.6ms preprocess, 307.5ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 2 cars, 5 trucks, 326.3ms
# Speed: 2.1ms preprocess, 326.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 cars, 3 trucks, 324.4ms
# Speed: 2.3ms preprocess, 324.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 3 trucks, 410.4ms
# Speed: 2.3ms preprocess, 410.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 2 cars, 4 trucks, 291.2ms
# Speed: 2.6ms preprocess, 291.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 3 cars, 4 trucks, 304.5ms
# Speed: 2.0ms preprocess, 304.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 4
1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 2 cars, 6 trucks, 394.5ms
# Speed: 4.3ms preprocess, 394.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 3 cars, 3 trucks, 334.8ms
# Speed: 2.9ms preprocess, 334.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 3 cars, 2 trucks, 329.9ms
# Speed: 5.3ms preprocess, 329.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 3 cars, 2 trucks, 393.6ms
# Speed: 4.2ms preprocess, 393.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 2 cars, 3 trucks, 397.1ms
# Speed: 2.6ms preprocess, 397.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 2 cars, 4 trucks, 388.2ms
# Speed: 5.1ms preprocess, 388.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 1 car, 1 truck, 347.2ms
# Speed: 3.5ms preprocess, 347.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 16 persons, 1 car, 1 truck, 336.1ms
# Speed: 2.2ms preprocess, 336.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 15 persons, 1 car, 1 truck, 360.8ms
# Speed: 3.1ms preprocess, 360.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 2 trucks, 425.2ms
# Speed: 6.2ms preprocess, 425.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 car, 1 truck, 361.7ms
# Speed: 3.0ms preprocess, 361.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 2 trucks, 383.4ms
# Speed: 5.5ms preprocess, 383.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 1 truck, 312.1ms
# Speed: 2.1ms preprocess, 312.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 2 trucks, 336.1ms
# Speed: 1.9ms preprocess, 336.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 3 trucks, 403.4ms
# Speed: 5.5ms preprocess, 403.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 2 cars, 2 trucks, 397.9ms
# Speed: 2.6ms preprocess, 397.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 3 cars, 1 bus, 7 trucks, 364.7ms
# Speed: 2.8ms preprocess, 364.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 4 cars, 2 trucks, 418.7ms
# Speed: 5.0ms preprocess, 418.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 4 cars, 4 trucks, 352.3ms
# Speed: 2.0ms preprocess, 352.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 4 cars, 3 trucks, 316.6ms
# Speed: 2.2ms preprocess, 316.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 car, 2 trucks, 372.7ms
# Speed: 2.0ms preprocess, 372.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 car, 2 trucks, 381.1ms
# Speed: 3.4ms preprocess, 381.1ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 3 cars, 2 trucks, 359.8ms
# Speed: 4.4ms preprocess, 359.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 2 cars, 1 truck, 359.8ms
# Speed: 2.5ms preprocess, 359.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 car, 3 trucks, 321.7ms
# Speed: 2.4ms preprocess, 321.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 2 cars, 2 trucks, 296.9ms
# Speed: 2.2ms preprocess, 296.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 car, 1 truck, 425.7ms
# Speed: 6.1ms preprocess, 425.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 3 cars, 1 bus, 4 trucks, 293.4ms
# Speed: 3.1ms preprocess, 293.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 3 cars, 1 bus, 3 trucks, 427.9ms
# Speed: 2.6ms preprocess, 427.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 7 cars, 5 trucks, 334.1ms
# Speed: 3.5ms preprocess, 334.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 3 cars, 3 trucks, 303.6ms
# Speed: 2.0ms preprocess, 303.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 4 cars, 3 trucks, 348.0ms
# Speed: 3.3ms preprocess, 348.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 2 cars, 3 trucks, 332.7ms
# Speed: 2.7ms preprocess, 332.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 1 car, 2 trucks, 357.8ms
# Speed: 3.3ms preprocess, 357.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons, 2 cars, 3 trucks, 344.7ms
# Speed: 3.3ms preprocess, 344.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 307.4ms
# Speed: 5.6ms preprocess, 307.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 3 cars, 2 trucks, 399.7ms
# Speed: 3.9ms preprocess, 399.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 1 car, 3 trucks, 379.6ms
# Speed: 1.9ms preprocess, 379.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 1 car, 3 trucks, 361.2ms
# Speed: 3.7ms preprocess, 361.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 3 trucks, 372.6ms
# Speed: 3.7ms preprocess, 372.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 334.2ms
# Speed: 2.2ms preprocess, 334.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 3 cars, 4 trucks, 295.9ms
# Speed: 2.2ms preprocess, 295.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 persons,
3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 3 trucks, 236.1ms
# Speed: 1.9ms preprocess, 236.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 3 trucks, 233.5ms
# Speed: 2.4ms preprocess, 233.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 2 cars, 3 trucks, 234.4ms
# Speed: 2.0ms preprocess, 234.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 3 trucks, 233.7ms
# Speed: 1.8ms preprocess, 233.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 3 trucks, 236.0ms
# Speed: 2.0ms preprocess, 236.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 4 trucks, 232.6ms
# Speed: 2.1ms preprocess, 232.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 4 trucks, 224.5ms
# Speed: 1.7ms preprocess, 224.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 3 trucks, 230.8ms
# Speed: 1.6ms preprocess, 230.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 1 car, 3 trucks, 230.1ms
# Speed: 1.9ms preprocess, 230.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 1 car, 3 trucks, 223.6ms
# Speed: 1.9ms preprocess, 223.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 3 trucks, 224.6ms
# Speed: 1.5ms preprocess, 224.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 2 cars, 3 trucks, 237.4ms
# Speed: 2.0ms preprocess, 237.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 4 trucks, 234.9ms
# Speed: 1.8ms preprocess, 234.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 3 cars, 3 trucks, 243.9ms
# Speed: 1.8ms preprocess, 243.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 1 bus, 4 trucks, 249.8ms
# Speed: 2.9ms preprocess, 249.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 4 trucks, 225.8ms
# Speed: 1.5ms preprocess, 225.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 4 trucks, 232.2ms
# Speed: 1.8ms preprocess, 232.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 2 cars, 3 trucks, 237.6ms
# Speed: 2.1ms preprocess, 237.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 1 bus, 3 trucks, 234.5ms
# Speed: 1.9ms preprocess, 234.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 4 cars, 2 trucks, 233.4ms
# Speed: 1.6ms preprocess, 233.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 1 bus, 5 trucks, 240.3ms
# Speed: 2.0ms preprocess, 240.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 3 cars, 2 trucks, 232.1ms
# Speed: 2.2ms preprocess, 232.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 3 trucks, 231.2ms
# Speed: 2.0ms preprocess, 231.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 4 trucks, 235.1ms
# Speed: 2.0ms preprocess, 235.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 3 cars, 2 trucks, 231.5ms
# Speed: 1.5ms preprocess, 231.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 3 trucks, 231.9ms
# Speed: 1.5ms preprocess, 231.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 3 cars, 3 trucks, 281.2ms
# Speed: 2.3ms preprocess, 281.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 2 cars, 3 trucks, 232.8ms
# Speed: 1.6ms preprocess, 232.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 4 trucks, 234.3ms
# Speed: 1.5ms preprocess, 234.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 4 trucks, 231.6ms
# Speed: 1.9ms preprocess, 231.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 2 trucks, 220.5ms
# Speed: 2.1ms preprocess, 220.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 213.4ms
# Speed: 2.0ms preprocess, 213.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 228.4ms
# Speed: 2.5ms preprocess, 228.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 4 persons, 1 car, 3 trucks, 231.5ms
# Speed: 2.3ms preprocess, 231.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 3 trucks, 230.2ms
# Speed: 1.8ms preprocess, 230.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 1 car, 3 trucks, 221.1ms
# Speed: 1.8ms preprocess, 221.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 car, 3 trucks, 232.1ms
# Speed: 1.9ms preprocess, 232.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 2 cars, 3 trucks, 230.5ms
# Speed: 1.9ms preprocess, 230.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 5 persons, 1 car, 3 trucks, 238.3ms
# Speed: 1.9ms preprocess, 238.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 6 persons, 2 cars, 5 trucks, 216.7ms
# Speed: 1.8ms preprocess, 216.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 2 cars, 4 trucks, 219.4ms
# Speed: 1.7ms preprocess, 219.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 7 persons, 1 car, 4 trucks, 226.6ms
# Speed: 1.7ms preprocess, 226.6ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 persons, 1 car, 3 trucks, 230.7ms
# Speed: 2.1ms preprocess, 230.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
