# %%
import cv2
import numpy as np
from ultralytics import YOLO


# defining function for creating a writer (for mp4 videos)
def create_video_writer(video_cap, output_filename):
    # grab the width, height, and fps of the frames in the video stream.
    frame_width = int(video_cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(video_cap.get(cv2.CAP_PROP_FPS))
    # initialize the FourCC and a video writer object
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    writer = cv2.VideoWriter(output_filename, fourcc, fps,
                             (frame_width, frame_height))
    return writer

# %%
from collections import defaultdict
import pandas as pd

# Load the YOLOv8 model
model = YOLO('yolov8s-obb.pt')

classNames = [
    'plane',
    'ship',
    'storage tank',
    'baseball diamond',
    'tennis court',
    'basketball court',
    'ground track field',
    'harbor',
    'bridge',
    'large vehicle',
    'small vehicle',
    'helicopter',
    'roundabout',
    'soccer ball field',
    'swimming pool'
]
positions = []
# Open the video file
video_path = "Puente_guambra2.mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])
# Store the class history
cls_history = defaultdict(lambda: [])

frame_number = 0

writer = create_video_writer(cap, f"{video_path}_annoted.mp4")

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        frame_number += 1

        results = model.predict(frame, conf=0.01, classes=[9,10])
        

        # Visualize the results on the frame
        annotated_frame = results[0].plot(line_width=2, font_size=0.01)
        
        writer.write(annotated_frame)
        # Get the boxes and track IDs
        
        if results[0].obb.xywhr is not None:
        
            boxes = results[0].obb.xywhr.cpu().tolist()
            clss = results[0].obb.cls.cpu().tolist()
            confs = results[0].obb.conf.cpu().tolist()


            # Plot the tracks
            for i, (box, cls, conf) in enumerate(zip(boxes, clss,confs)):
                x, y, w, h, r = box
                
                positions.append([int(frame_number), int(i+1), str(classNames[int(cls)]), float(conf), float(x), float(y),float(w), float(h), float(r)])  # x, y center point

        # Display the annotated frame
        cv2.imshow("YOLOv8 Obb", cv2.resize(annotated_frame, (1920, 1080)))

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

df = pd.DataFrame(positions, columns=["frame_number", "id", "class","conf", "cx", "cy", "w", "h", "r"])

# Release the video capture object and close the display window
cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 544x1024 841.2ms
# Speed: 4.8ms preprocess, 841.2ms inference, 437.0ms postprocess per image at shape (1, 3, 544, 1024)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/arthur/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# 0: 544x1024 756.1ms
# Speed: 4.8ms preprocess, 756.1ms inference, 22.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 795.4ms
# Speed: 3.8ms preprocess, 795.4ms inference, 38.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 768.2ms
# Speed: 3.3ms preprocess, 768.2ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 241.3ms
# Speed: 3.0ms preprocess, 241.3ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 256.5ms
# Speed: 4.1ms preprocess, 256.5ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 236.5ms
# Speed: 3.7ms preprocess, 236.5ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 183.8ms
# Speed: 4.4ms preprocess, 183.8ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 212.4ms
# Speed: 3.6ms preprocess, 212.4ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 196.1ms
# Speed: 3.7ms preprocess, 196.1ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.8ms
# Speed: 3.6ms preprocess, 213.8ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 193.6ms
# Speed: 3.0ms preprocess, 193.6ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.7ms
# Speed: 3.5ms preprocess, 184.7ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.8ms
# Speed: 3.0ms preprocess, 230.8ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.3ms
# Speed: 5.1ms preprocess, 203.3ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 228.2ms
# Speed: 3.2ms preprocess, 228.2ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 189.2ms
# Speed: 3.4ms preprocess, 189.2ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 193.1ms
# Speed: 3.3ms preprocess, 193.1ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 174.6ms
# Speed: 3.2ms preprocess, 174.6ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.1ms
# Speed: 3.4ms preprocess, 195.1ms inference, 6.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.0ms
# Speed: 3.5ms preprocess, 195.0ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.2ms
# Speed: 3.7ms preprocess, 251.2ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.3ms
# Speed: 3.7ms preprocess, 222.3ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 174.0ms
# Speed: 3.5ms preprocess, 174.0ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.5ms
# Speed: 3.7ms preprocess, 185.5ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.2ms
# Speed: 4.5ms preprocess, 185.2ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.4ms
# Speed: 3.4ms preprocess, 202.4ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.2ms
# Speed: 3.6ms preprocess, 203.2ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 176.6ms
# Speed: 4.1ms preprocess, 176.6ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 191.0ms
# Speed: 3.6ms preprocess, 191.0ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 280.9ms
# Speed: 3.9ms preprocess, 280.9ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.8ms
# Speed: 3.5ms preprocess, 220.8ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 214.3ms
# Speed: 4.2ms preprocess, 214.3ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 200.3ms
# Speed: 3.3ms preprocess, 200.3ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.5ms
# Speed: 3.8ms preprocess, 217.5ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 166.4ms
# Speed: 3.7ms preprocess, 166.4ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 207.9ms
# Speed: 3.0ms preprocess, 207.9ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.6ms
# Speed: 3.7ms preprocess, 219.6ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 236.9ms
# Speed: 3.6ms preprocess, 236.9ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 196.3ms
# Speed: 3.2ms preprocess, 196.3ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.8ms
# Speed: 3.5ms preprocess, 210.8ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 194.8ms
# Speed: 3.2ms preprocess, 194.8ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 176.8ms
# Speed: 3.6ms preprocess, 176.8ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 259.8ms
# Speed: 4.1ms preprocess, 259.8ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.4ms
# Speed: 3.3ms preprocess, 217.4ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.3ms
# Speed: 3.5ms preprocess, 230.3ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 224.7ms
# Speed: 3.5ms preprocess, 224.7ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 193.8ms
# Speed: 3.9ms preprocess, 193.8ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.8ms
# Speed: 3.9ms preprocess, 213.8ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.6ms
# Speed: 3.9ms preprocess, 164.6ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.0ms
# Speed: 3.2ms preprocess, 202.0ms inference, 7.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 204.3ms
# Speed: 4.9ms preprocess, 204.3ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.8ms
# Speed: 3.6ms preprocess, 185.8ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.9ms
# Speed: 4.5ms preprocess, 230.9ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.4ms
# Speed: 4.4ms preprocess, 201.4ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 254.4ms
# Speed: 4.0ms preprocess, 254.4ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.5ms
# Speed: 4.9ms preprocess, 237.5ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 200.6ms
# Speed: 3.3ms preprocess, 200.6ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 259.6ms
# Speed: 5.6ms preprocess, 259.6ms inference, 10.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 319.8ms
# Speed: 9.0ms preprocess, 319.8ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 236.9ms
# Speed: 9.3ms preprocess, 236.9ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.6ms
# Speed: 5.1ms preprocess, 242.6ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.9ms
# Speed: 5.1ms preprocess, 231.9ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 228.9ms
# Speed: 3.6ms preprocess, 228.9ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 211.9ms
# Speed: 6.1ms preprocess, 211.9ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.7ms
# Speed: 3.8ms preprocess, 222.7ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.6ms
# Speed: 4.2ms preprocess, 222.6ms inference, 10.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 258.9ms
# Speed: 7.4ms preprocess, 258.9ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 205.6ms
# Speed: 4.5ms preprocess, 205.6ms inference, 10.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 236.9ms
# Speed: 4.2ms preprocess, 236.9ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.9ms
# Speed: 4.5ms preprocess, 206.9ms inference, 10.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 209.9ms
# Speed: 3.6ms preprocess, 209.9ms inference, 10.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 214.7ms
# Speed: 4.2ms preprocess, 214.7ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.7ms
# Speed: 3.7ms preprocess, 203.7ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 250.1ms
# Speed: 4.1ms preprocess, 250.1ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 187.9ms
# Speed: 4.3ms preprocess, 187.9ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 238.9ms
# Speed: 4.8ms preprocess, 238.9ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.0ms
# Speed: 3.6ms preprocess, 213.0ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.6ms
# Speed: 5.9ms preprocess, 217.6ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 216.4ms
# Speed: 4.8ms preprocess, 216.4ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 200.2ms
# Speed: 4.7ms preprocess, 200.2ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.8ms
# Speed: 4.0ms preprocess, 197.8ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 207.8ms
# Speed: 3.6ms preprocess, 207.8ms inference, 10.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.3ms
# Speed: 3.4ms preprocess, 206.3ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.8ms
# Speed: 3.1ms preprocess, 201.8ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 246.7ms
# Speed: 4.2ms preprocess, 246.7ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.5ms
# Speed: 4.9ms preprocess, 184.5ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 249.0ms
# Speed: 3.7ms preprocess, 249.0ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.9ms
# Speed: 5.5ms preprocess, 197.9ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.8ms
# Speed: 4.0ms preprocess, 184.8ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.3ms
# Speed: 3.6ms preprocess, 210.3ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 212.9ms
# Speed: 3.1ms preprocess, 212.9ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.8ms
# Speed: 3.7ms preprocess, 251.8ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 200.7ms
# Speed: 5.0ms preprocess, 200.7ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.4ms
# Speed: 4.2ms preprocess, 197.4ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 174.6ms
# Speed: 3.8ms preprocess, 174.6ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 249.9ms
# Speed: 4.1ms preprocess, 249.9ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.4ms
# Speed: 3.3ms preprocess, 213.4ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.7ms
# Speed: 3.8ms preprocess, 223.7ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.9ms
# Speed: 4.5ms preprocess, 199.9ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.6ms
# Speed: 3.8ms preprocess, 234.6ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.2ms
# Speed: 3.4ms preprocess, 219.2ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.2ms
# Speed: 3.6ms preprocess, 208.2ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.7ms
# Speed: 3.7ms preprocess, 206.7ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.7ms
# Speed: 4.9ms preprocess, 219.7ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 169.6ms
# Speed: 3.8ms preprocess, 169.6ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.0ms
# Speed: 3.7ms preprocess, 213.0ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.7ms
# Speed: 3.6ms preprocess, 208.7ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 250.2ms
# Speed: 4.5ms preprocess, 250.2ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 188.5ms
# Speed: 3.5ms preprocess, 188.5ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.5ms
# Speed: 4.0ms preprocess, 199.5ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.9ms
# Speed: 3.7ms preprocess, 208.9ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 205.4ms
# Speed: 3.6ms preprocess, 205.4ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.1ms
# Speed: 4.0ms preprocess, 213.1ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.0ms
# Speed: 3.7ms preprocess, 195.0ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 189.0ms
# Speed: 3.7ms preprocess, 189.0ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.5ms
# Speed: 3.6ms preprocess, 203.5ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 250.1ms
# Speed: 4.2ms preprocess, 250.1ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 186.4ms
# Speed: 3.3ms preprocess, 186.4ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.7ms
# Speed: 3.7ms preprocess, 231.7ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.5ms
# Speed: 3.4ms preprocess, 234.5ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 177.0ms
# Speed: 3.5ms preprocess, 177.0ms inference, 6.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.4ms
# Speed: 4.2ms preprocess, 240.4ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 174.5ms
# Speed: 4.2ms preprocess, 174.5ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.7ms
# Speed: 3.4ms preprocess, 218.7ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.6ms
# Speed: 4.8ms preprocess, 221.6ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 192.6ms
# Speed: 4.0ms preprocess, 192.6ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 188.6ms
# Speed: 3.5ms preprocess, 188.6ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.8ms
# Speed: 3.7ms preprocess, 208.8ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 205.7ms
# Speed: 3.6ms preprocess, 205.7ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 181.7ms
# Speed: 3.4ms preprocess, 181.7ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 198.8ms
# Speed: 3.6ms preprocess, 198.8ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 211.2ms
# Speed: 4.3ms preprocess, 211.2ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 235.7ms
# Speed: 3.6ms preprocess, 235.7ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.7ms
# Speed: 3.1ms preprocess, 210.7ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 174.2ms
# Speed: 3.6ms preprocess, 174.2ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.7ms
# Speed: 3.2ms preprocess, 202.7ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.9ms
# Speed: 4.4ms preprocess, 185.9ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.4ms
# Speed: 3.6ms preprocess, 206.4ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.0ms
# Speed: 3.9ms preprocess, 217.0ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 182.1ms
# Speed: 3.7ms preprocess, 182.1ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 226.0ms
# Speed: 4.3ms preprocess, 226.0ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.1ms
# Speed: 3.6ms preprocess, 217.1ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.5ms
# Speed: 4.5ms preprocess, 240.5ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 194.5ms
# Speed: 3.3ms preprocess, 194.5ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 194.9ms
# Speed: 4.2ms preprocess, 194.9ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 216.3ms
# Speed: 3.8ms preprocess, 216.3ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 198.5ms
# Speed: 3.7ms preprocess, 198.5ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 179.7ms
# Speed: 4.3ms preprocess, 179.7ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.7ms
# Speed: 3.6ms preprocess, 201.7ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 246.2ms
# Speed: 11.1ms preprocess, 246.2ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.6ms
# Speed: 3.8ms preprocess, 213.6ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 215.6ms
# Speed: 4.3ms preprocess, 215.6ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.6ms
# Speed: 4.6ms preprocess, 208.6ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.2ms
# Speed: 4.1ms preprocess, 197.2ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 216.6ms
# Speed: 4.0ms preprocess, 216.6ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 262.4ms
# Speed: 3.6ms preprocess, 262.4ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.3ms
# Speed: 3.7ms preprocess, 184.3ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 209.5ms
# Speed: 3.7ms preprocess, 209.5ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 175.7ms
# Speed: 3.2ms preprocess, 175.7ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 267.1ms
# Speed: 3.7ms preprocess, 267.1ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 181.4ms
# Speed: 4.2ms preprocess, 181.4ms inference, 7.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 192.9ms
# Speed: 3.7ms preprocess, 192.9ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 198.9ms
# Speed: 3.6ms preprocess, 198.9ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.7ms
# Speed: 4.2ms preprocess, 203.7ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.8ms
# Speed: 3.6ms preprocess, 233.8ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 254.3ms
# Speed: 3.7ms preprocess, 254.3ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.0ms
# Speed: 4.0ms preprocess, 219.0ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 179.1ms
# Speed: 4.0ms preprocess, 179.1ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 211.0ms
# Speed: 3.7ms preprocess, 211.0ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 226.5ms
# Speed: 4.0ms preprocess, 226.5ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.3ms
# Speed: 3.9ms preprocess, 220.3ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.5ms
# Speed: 4.3ms preprocess, 199.5ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 216.3ms
# Speed: 3.3ms preprocess, 216.3ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 232.6ms
# Speed: 3.3ms preprocess, 232.6ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.9ms
# Speed: 3.7ms preprocess, 202.9ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.4ms
# Speed: 3.8ms preprocess, 230.4ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 212.9ms
# Speed: 4.3ms preprocess, 212.9ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.3ms
# Speed: 4.6ms preprocess, 223.3ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.6ms
# Speed: 5.0ms preprocess, 217.6ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.9ms
# Speed: 3.7ms preprocess, 197.9ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.0ms
# Speed: 4.2ms preprocess, 225.0ms inference, 6.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.7ms
# Speed: 4.6ms preprocess, 203.7ms inference, 7.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 196.1ms
# Speed: 4.8ms preprocess, 196.1ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.3ms
# Speed: 3.7ms preprocess, 223.3ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 176.4ms
# Speed: 3.6ms preprocess, 176.4ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 216.4ms
# Speed: 4.1ms preprocess, 216.4ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 205.1ms
# Speed: 3.3ms preprocess, 205.1ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 214.4ms
# Speed: 3.6ms preprocess, 214.4ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 277.2ms
# Speed: 5.0ms preprocess, 277.2ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 204.4ms
# Speed: 3.7ms preprocess, 204.4ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.2ms
# Speed: 3.7ms preprocess, 184.2ms inference, 6.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.8ms
# Speed: 4.3ms preprocess, 231.8ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 209.4ms
# Speed: 3.4ms preprocess, 209.4ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.4ms
# Speed: 3.5ms preprocess, 223.4ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.5ms
# Speed: 4.2ms preprocess, 251.5ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 186.7ms
# Speed: 5.7ms preprocess, 186.7ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 197.9ms
# Speed: 4.0ms preprocess, 197.9ms inference, 6.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 246.4ms
# Speed: 3.2ms preprocess, 246.4ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.5ms
# Speed: 3.6ms preprocess, 203.5ms inference, 7.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.7ms
# Speed: 4.2ms preprocess, 217.7ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.7ms
# Speed: 3.7ms preprocess, 203.7ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.7ms
# Speed: 3.7ms preprocess, 222.7ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 183.6ms
# Speed: 4.2ms preprocess, 183.6ms inference, 7.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 200.4ms
# Speed: 4.0ms preprocess, 200.4ms inference, 6.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 227.4ms
# Speed: 4.1ms preprocess, 227.4ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 271.5ms
# Speed: 3.3ms preprocess, 271.5ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 227.1ms
# Speed: 5.0ms preprocess, 227.1ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.9ms
# Speed: 3.8ms preprocess, 219.9ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 190.7ms
# Speed: 3.3ms preprocess, 190.7ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.1ms
# Speed: 4.1ms preprocess, 195.1ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.6ms
# Speed: 4.3ms preprocess, 221.6ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 226.6ms
# Speed: 3.9ms preprocess, 226.6ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.7ms
# Speed: 3.8ms preprocess, 221.7ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 283.2ms
# Speed: 4.6ms preprocess, 283.2ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 263.5ms
# Speed: 4.9ms preprocess, 263.5ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.7ms
# Speed: 3.7ms preprocess, 225.7ms inference, 7.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.4ms
# Speed: 3.3ms preprocess, 208.4ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.8ms
# Speed: 5.6ms preprocess, 222.8ms inference, 6.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 198.1ms
# Speed: 5.2ms preprocess, 198.1ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 287.6ms
# Speed: 3.9ms preprocess, 287.6ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.0ms
# Speed: 4.9ms preprocess, 251.0ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.1ms
# Speed: 4.1ms preprocess, 237.1ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 260.5ms
# Speed: 7.8ms preprocess, 260.5ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 255.3ms
# Speed: 6.2ms preprocess, 255.3ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 282.6ms
# Speed: 3.8ms preprocess, 282.6ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 258.5ms
# Speed: 3.7ms preprocess, 258.5ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 280.7ms
# Speed: 4.7ms preprocess, 280.7ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 253.6ms
# Speed: 6.1ms preprocess, 253.6ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.3ms
# Speed: 4.4ms preprocess, 240.3ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 264.6ms
# Speed: 4.6ms preprocess, 264.6ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 226.9ms
# Speed: 7.0ms preprocess, 226.9ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.8ms
# Speed: 7.7ms preprocess, 242.8ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.8ms
# Speed: 4.1ms preprocess, 240.8ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.9ms
# Speed: 5.7ms preprocess, 234.9ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 283.6ms
# Speed: 8.2ms preprocess, 283.6ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.1ms
# Speed: 5.4ms preprocess, 237.1ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 264.1ms
# Speed: 11.1ms preprocess, 264.1ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 244.0ms
# Speed: 15.6ms preprocess, 244.0ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 270.4ms
# Speed: 4.2ms preprocess, 270.4ms inference, 11.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.7ms
# Speed: 4.1ms preprocess, 195.7ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.5ms
# Speed: 5.5ms preprocess, 242.5ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.2ms
# Speed: 6.1ms preprocess, 223.2ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.8ms
# Speed: 4.8ms preprocess, 206.8ms inference, 6.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 256.2ms
# Speed: 4.4ms preprocess, 256.2ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 209.8ms
# Speed: 3.9ms preprocess, 209.8ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 239.9ms
# Speed: 5.4ms preprocess, 239.9ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.2ms
# Speed: 3.5ms preprocess, 225.2ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.6ms
# Speed: 4.0ms preprocess, 237.6ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.9ms
# Speed: 3.5ms preprocess, 225.9ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.7ms
# Speed: 3.7ms preprocess, 220.7ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.0ms
# Speed: 4.1ms preprocess, 237.0ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.6ms
# Speed: 4.9ms preprocess, 231.6ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.1ms
# Speed: 4.8ms preprocess, 237.1ms inference, 7.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 239.5ms
# Speed: 3.7ms preprocess, 239.5ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.6ms
# Speed: 4.1ms preprocess, 223.6ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.3ms
# Speed: 10.5ms preprocess, 231.3ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 232.3ms
# Speed: 6.5ms preprocess, 232.3ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.4ms
# Speed: 6.3ms preprocess, 230.4ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.0ms
# Speed: 4.6ms preprocess, 242.0ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 187.0ms
# Speed: 4.0ms preprocess, 187.0ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.5ms
# Speed: 5.7ms preprocess, 225.5ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.5ms
# Speed: 3.7ms preprocess, 184.5ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.4ms
# Speed: 4.6ms preprocess, 219.4ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 278.3ms
# Speed: 5.4ms preprocess, 278.3ms inference, 10.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 194.2ms
# Speed: 5.7ms preprocess, 194.2ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.2ms
# Speed: 4.3ms preprocess, 242.2ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 247.1ms
# Speed: 4.6ms preprocess, 247.1ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 230.5ms
# Speed: 11.2ms preprocess, 230.5ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 188.1ms
# Speed: 5.1ms preprocess, 188.1ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 196.8ms
# Speed: 4.7ms preprocess, 196.8ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 225.8ms
# Speed: 7.8ms preprocess, 225.8ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 249.6ms
# Speed: 5.6ms preprocess, 249.6ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.8ms
# Speed: 3.5ms preprocess, 201.8ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 226.6ms
# Speed: 4.0ms preprocess, 226.6ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 180.0ms
# Speed: 3.4ms preprocess, 180.0ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 262.4ms
# Speed: 3.9ms preprocess, 262.4ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 209.2ms
# Speed: 4.2ms preprocess, 209.2ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 238.7ms
# Speed: 3.3ms preprocess, 238.7ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.2ms
# Speed: 4.0ms preprocess, 223.2ms inference, 9.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.4ms
# Speed: 5.0ms preprocess, 233.4ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.5ms
# Speed: 4.5ms preprocess, 221.5ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 214.8ms
# Speed: 3.9ms preprocess, 214.8ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.0ms
# Speed: 5.6ms preprocess, 210.0ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 215.4ms
# Speed: 5.9ms preprocess, 215.4ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.7ms
# Speed: 6.3ms preprocess, 217.7ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.3ms
# Speed: 6.2ms preprocess, 201.3ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 250.1ms
# Speed: 4.5ms preprocess, 250.1ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 212.1ms
# Speed: 4.2ms preprocess, 212.1ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 249.5ms
# Speed: 3.7ms preprocess, 249.5ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 193.3ms
# Speed: 3.6ms preprocess, 193.3ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.1ms
# Speed: 3.7ms preprocess, 206.1ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.9ms
# Speed: 5.6ms preprocess, 222.9ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 260.4ms
# Speed: 4.7ms preprocess, 260.4ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.7ms
# Speed: 4.0ms preprocess, 208.7ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.9ms
# Speed: 5.8ms preprocess, 240.9ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 242.3ms
# Speed: 5.6ms preprocess, 242.3ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 215.5ms
# Speed: 6.4ms preprocess, 215.5ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.4ms
# Speed: 4.7ms preprocess, 219.4ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.6ms
# Speed: 3.7ms preprocess, 223.6ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.9ms
# Speed: 4.6ms preprocess, 195.9ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.9ms
# Speed: 6.6ms preprocess, 219.9ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 222.4ms
# Speed: 4.4ms preprocess, 222.4ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.7ms
# Speed: 4.1ms preprocess, 251.7ms inference, 7.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 262.2ms
# Speed: 7.9ms preprocess, 262.2ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.8ms
# Speed: 4.4ms preprocess, 201.8ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 206.1ms
# Speed: 5.5ms preprocess, 206.1ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 239.8ms
# Speed: 4.3ms preprocess, 239.8ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 171.8ms
# Speed: 4.2ms preprocess, 171.8ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 245.0ms
# Speed: 5.5ms preprocess, 245.0ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.9ms
# Speed: 5.7ms preprocess, 234.9ms inference, 7.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 232.1ms
# Speed: 3.5ms preprocess, 232.1ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 211.9ms
# Speed: 3.4ms preprocess, 211.9ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.2ms
# Speed: 3.9ms preprocess, 220.2ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.8ms
# Speed: 3.3ms preprocess, 213.8ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.4ms
# Speed: 3.9ms preprocess, 218.4ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 248.1ms
# Speed: 3.8ms preprocess, 248.1ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 229.2ms
# Speed: 4.7ms preprocess, 229.2ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.9ms
# Speed: 5.1ms preprocess, 217.9ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 189.1ms
# Speed: 4.7ms preprocess, 189.1ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 229.6ms
# Speed: 5.2ms preprocess, 229.6ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.5ms
# Speed: 4.1ms preprocess, 210.5ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 284.5ms
# Speed: 4.9ms preprocess, 284.5ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.8ms
# Speed: 3.7ms preprocess, 221.8ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 215.3ms
# Speed: 4.7ms preprocess, 215.3ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.2ms
# Speed: 4.0ms preprocess, 251.2ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.1ms
# Speed: 13.9ms preprocess, 199.1ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 257.9ms
# Speed: 4.0ms preprocess, 257.9ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 190.4ms
# Speed: 3.4ms preprocess, 190.4ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.6ms
# Speed: 3.9ms preprocess, 220.6ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 208.0ms
# Speed: 5.5ms preprocess, 208.0ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 228.8ms
# Speed: 3.8ms preprocess, 228.8ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.2ms
# Speed: 4.3ms preprocess, 199.2ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.3ms
# Speed: 6.1ms preprocess, 221.3ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 224.8ms
# Speed: 3.5ms preprocess, 224.8ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.1ms
# Speed: 3.8ms preprocess, 202.1ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 201.1ms
# Speed: 4.8ms preprocess, 201.1ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 231.6ms
# Speed: 4.6ms preprocess, 231.6ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 180.3ms
# Speed: 4.5ms preprocess, 180.3ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 243.2ms
# Speed: 5.6ms preprocess, 243.2ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.7ms
# Speed: 4.2ms preprocess, 233.7ms inference, 6.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.4ms
# Speed: 6.1ms preprocess, 221.4ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 207.1ms
# Speed: 4.2ms preprocess, 207.1ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 244.2ms
# Speed: 4.7ms preprocess, 244.2ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.0ms
# Speed: 5.2ms preprocess, 218.0ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 224.7ms
# Speed: 4.1ms preprocess, 224.7ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 184.1ms
# Speed: 3.4ms preprocess, 184.1ms inference, 7.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 228.5ms
# Speed: 4.6ms preprocess, 228.5ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 243.8ms
# Speed: 4.3ms preprocess, 243.8ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 191.3ms
# Speed: 4.7ms preprocess, 191.3ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 229.0ms
# Speed: 3.2ms preprocess, 229.0ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 199.2ms
# Speed: 5.5ms preprocess, 199.2ms inference, 7.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 207.3ms
# Speed: 3.8ms preprocess, 207.3ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 255.2ms
# Speed: 3.3ms preprocess, 255.2ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.9ms
# Speed: 3.6ms preprocess, 218.9ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 202.3ms
# Speed: 4.0ms preprocess, 202.3ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.1ms
# Speed: 5.9ms preprocess, 220.1ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.9ms
# Speed: 3.2ms preprocess, 217.9ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 235.3ms
# Speed: 3.5ms preprocess, 235.3ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.4ms
# Speed: 6.3ms preprocess, 221.4ms inference, 8.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 210.1ms
# Speed: 5.4ms preprocess, 210.1ms inference, 6.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.7ms
# Speed: 3.3ms preprocess, 218.7ms inference, 7.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 232.0ms
# Speed: 6.5ms preprocess, 232.0ms inference, 7.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.9ms
# Speed: 4.1ms preprocess, 233.9ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 207.5ms
# Speed: 6.0ms preprocess, 207.5ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 223.8ms
# Speed: 4.6ms preprocess, 223.8ms inference, 7.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 191.1ms
# Speed: 3.9ms preprocess, 191.1ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.3ms
# Speed: 4.4ms preprocess, 203.3ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 221.6ms
# Speed: 3.9ms preprocess, 221.6ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 211.9ms
# Speed: 4.6ms preprocess, 211.9ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.1ms
# Speed: 6.0ms preprocess, 220.1ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 321.1ms
# Speed: 3.5ms preprocess, 321.1ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 187.7ms
# Speed: 4.1ms preprocess, 187.7ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.6ms
# Speed: 6.7ms preprocess, 233.6ms inference, 10.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 219.3ms
# Speed: 4.2ms preprocess, 219.3ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.6ms
# Speed: 4.1ms preprocess, 234.6ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 271.0ms
# Speed: 5.9ms preprocess, 271.0ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 181.0ms
# Speed: 4.8ms preprocess, 181.0ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 217.8ms
# Speed: 4.1ms preprocess, 217.8ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 249.4ms
# Speed: 4.9ms preprocess, 249.4ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 237.7ms
# Speed: 3.7ms preprocess, 237.7ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 235.1ms
# Speed: 4.6ms preprocess, 235.1ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.6ms
# Speed: 4.4ms preprocess, 195.6ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 235.0ms
# Speed: 6.9ms preprocess, 235.0ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 212.7ms
# Speed: 3.7ms preprocess, 212.7ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.0ms
# Speed: 4.7ms preprocess, 233.0ms inference, 7.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 204.7ms
# Speed: 3.5ms preprocess, 204.7ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 233.3ms
# Speed: 5.3ms preprocess, 233.3ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 220.2ms
# Speed: 3.8ms preprocess, 220.2ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 218.3ms
# Speed: 4.5ms preprocess, 218.3ms inference, 7.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.1ms
# Speed: 3.4ms preprocess, 203.1ms inference, 7.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 203.1ms
# Speed: 4.2ms preprocess, 203.1ms inference, 6.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.5ms
# Speed: 3.8ms preprocess, 185.5ms inference, 6.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 251.6ms
# Speed: 3.7ms preprocess, 251.6ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 234.3ms
# Speed: 5.7ms preprocess, 234.3ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 229.1ms
# Speed: 4.0ms preprocess, 229.1ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 245.5ms
# Speed: 4.0ms preprocess, 245.5ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 240.5ms
# ...
#
# 0: 544x1024 164.6ms
# Speed: 3.4ms preprocess, 164.6ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 170.5ms
# Speed: 4.1ms preprocess, 170.5ms inference, 11.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 165.8ms
# Speed: 4.0ms preprocess, 165.8ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 204.6ms
# Speed: 3.1ms preprocess, 204.6ms inference, 11.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.3ms
# Speed: 3.7ms preprocess, 158.3ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.4ms
# Speed: 3.8ms preprocess, 164.4ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 171.4ms
# Speed: 3.2ms preprocess, 171.4ms inference, 11.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.2ms
# Speed: 3.5ms preprocess, 164.2ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.2ms
# Speed: 3.5ms preprocess, 157.2ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 156.4ms
# Speed: 3.4ms preprocess, 156.4ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.5ms
# Speed: 3.2ms preprocess, 162.5ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.0ms
# Speed: 2.9ms preprocess, 162.0ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 166.0ms
# Speed: 3.7ms preprocess, 166.0ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 170.2ms
# Speed: 3.5ms preprocess, 170.2ms inference, 10.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 167.6ms
# Speed: 3.9ms preprocess, 167.6ms inference, 10.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.6ms
# Speed: 4.0ms preprocess, 163.6ms inference, 10.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 176.0ms
# Speed: 4.2ms preprocess, 176.0ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.0ms
# Speed: 3.0ms preprocess, 157.0ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.5ms
# Speed: 3.0ms preprocess, 157.5ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.4ms
# Speed: 3.5ms preprocess, 158.4ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.1ms
# Speed: 3.0ms preprocess, 161.1ms inference, 8.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 167.4ms
# Speed: 4.0ms preprocess, 167.4ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 170.1ms
# Speed: 4.5ms preprocess, 170.1ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.5ms
# Speed: 3.2ms preprocess, 161.5ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.3ms
# Speed: 3.9ms preprocess, 162.3ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 168.9ms
# Speed: 3.4ms preprocess, 168.9ms inference, 7.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 169.1ms
# Speed: 3.9ms preprocess, 169.1ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.2ms
# Speed: 3.2ms preprocess, 158.2ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.0ms
# Speed: 3.3ms preprocess, 159.0ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.9ms
# Speed: 3.6ms preprocess, 163.9ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.3ms
# Speed: 3.8ms preprocess, 161.3ms inference, 10.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.7ms
# Speed: 2.7ms preprocess, 158.7ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 155.3ms
# Speed: 3.6ms preprocess, 155.3ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.6ms
# Speed: 3.4ms preprocess, 159.6ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.6ms
# Speed: 3.7ms preprocess, 163.6ms inference, 9.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.6ms
# Speed: 3.0ms preprocess, 157.6ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.3ms
# Speed: 3.2ms preprocess, 160.3ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.9ms
# Speed: 4.0ms preprocess, 161.9ms inference, 10.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 205.6ms
# Speed: 3.4ms preprocess, 205.6ms inference, 13.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.4ms
# Speed: 3.1ms preprocess, 162.4ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 149.7ms
# Speed: 2.8ms preprocess, 149.7ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.3ms
# Speed: 2.7ms preprocess, 158.3ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 155.8ms
# Speed: 3.1ms preprocess, 155.8ms inference, 8.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.2ms
# Speed: 3.5ms preprocess, 163.2ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.0ms
# Speed: 3.2ms preprocess, 159.0ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.8ms
# Speed: 3.5ms preprocess, 162.8ms inference, 8.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.1ms
# Speed: 3.5ms preprocess, 157.1ms inference, 8.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 156.5ms
# Speed: 3.4ms preprocess, 156.5ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 166.7ms
# Speed: 2.8ms preprocess, 166.7ms inference, 9.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.2ms
# Speed: 3.4ms preprocess, 160.2ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 155.8ms
# Speed: 3.2ms preprocess, 155.8ms inference, 9.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 165.4ms
# Speed: 2.8ms preprocess, 165.4ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.9ms
# Speed: 5.3ms preprocess, 160.9ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.9ms
# Speed: 9.2ms preprocess, 160.9ms inference, 8.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.1ms
# Speed: 4.7ms preprocess, 158.1ms inference, 8.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.0ms
# Speed: 3.9ms preprocess, 160.0ms inference, 8.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 156.0ms
# Speed: 2.8ms preprocess, 156.0ms inference, 8.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 213.2ms
# Speed: 3.1ms preprocess, 213.2ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.2ms
# Speed: 3.7ms preprocess, 157.2ms inference, 9.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 153.9ms
# Speed: 3.3ms preprocess, 153.9ms inference, 10.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.4ms
# Speed: 3.8ms preprocess, 164.4ms inference, 10.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 171.1ms
# Speed: 3.9ms preprocess, 171.1ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.1ms
# Speed: 3.3ms preprocess, 163.1ms inference, 10.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.9ms
# Speed: 3.8ms preprocess, 159.9ms inference, 10.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.8ms
# Speed: 4.0ms preprocess, 164.8ms inference, 10.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 154.6ms
# Speed: 3.7ms preprocess, 154.6ms inference, 9.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 154.5ms
# Speed: 3.4ms preprocess, 154.5ms inference, 10.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 168.6ms
# Speed: 3.4ms preprocess, 168.6ms inference, 11.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.7ms
# Speed: 3.4ms preprocess, 163.7ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.2ms
# Speed: 3.6ms preprocess, 158.2ms inference, 10.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 185.0ms
# Speed: 25.2ms preprocess, 185.0ms inference, 12.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.8ms
# Speed: 3.4ms preprocess, 162.8ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 163.9ms
# Speed: 3.9ms preprocess, 163.9ms inference, 11.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.0ms
# Speed: 3.6ms preprocess, 162.0ms inference, 10.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.7ms
# Speed: 3.9ms preprocess, 164.7ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 165.0ms
# Speed: 3.7ms preprocess, 165.0ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 170.3ms
# Speed: 3.8ms preprocess, 170.3ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 169.9ms
# Speed: 3.9ms preprocess, 169.9ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.8ms
# Speed: 3.3ms preprocess, 159.8ms inference, 10.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 157.0ms
# Speed: 3.8ms preprocess, 157.0ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 170.9ms
# Speed: 3.2ms preprocess, 170.9ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 165.0ms
# Speed: 3.6ms preprocess, 165.0ms inference, 11.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.2ms
# Speed: 3.8ms preprocess, 161.2ms inference, 10.8ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.2ms
# Speed: 3.7ms preprocess, 158.2ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 168.4ms
# Speed: 3.7ms preprocess, 168.4ms inference, 11.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.2ms
# Speed: 3.5ms preprocess, 161.2ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.7ms
# Speed: 3.5ms preprocess, 162.7ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.1ms
# Speed: 3.2ms preprocess, 161.1ms inference, 11.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 154.3ms
# Speed: 3.1ms preprocess, 154.3ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 195.5ms
# Speed: 3.2ms preprocess, 195.5ms inference, 9.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 159.3ms
# Speed: 3.9ms preprocess, 159.3ms inference, 10.9ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.1ms
# Speed: 3.2ms preprocess, 158.1ms inference, 9.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 154.2ms
# Speed: 2.9ms preprocess, 154.2ms inference, 9.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.3ms
# Speed: 3.1ms preprocess, 162.3ms inference, 11.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 162.4ms
# Speed: 2.9ms preprocess, 162.4ms inference, 11.7ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 161.5ms
# Speed: 3.2ms preprocess, 161.5ms inference, 12.0ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 153.0ms
# Speed: 2.7ms preprocess, 153.0ms inference, 10.4ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 164.8ms
# Speed: 3.6ms preprocess, 164.8ms inference, 11.3ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 156.3ms
# Speed: 3.7ms preprocess, 156.3ms inference, 10.1ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.5ms
# Speed: 3.6ms preprocess, 158.5ms inference, 10.6ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 160.7ms
# Speed: 3.2ms preprocess, 160.7ms inference, 11.5ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 158.4ms
# Speed: 3.2ms preprocess, 158.4ms inference, 12.2ms postprocess per image at shape (1, 3, 544, 1024)
#
# 0: 544x1024 154.9ms
# Speed: 3.3ms preprocess, 154.9ms inference, 12.5ms postprocess per image at shape (1, 3, 544, 1024)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 8 columns passed, passed data had 9 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 78
#      74     else:
#      75         # Break the loop if the end of the video is reached
#      76         break
# ---> 78 df = pd.DataFrame(positions, columns=["frame_number", "id", "class", "x", "y", "w", "h", "r"])
#      80 # Release the video capture object and close the display window
#      81 cap.release()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:806, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804     if columns is not None:
#     805         columns = ensure_index(columns)
# --> 806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     809         data,
#     810         columns,
#     811         index,  # type: ignore[arg-type]
#     812         dtype,
#     813     )
#     814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
#    (...)
#     819         typ=manager,
#     820     )
#     821 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 8 columns passed, passed data had 9 columns

# %%
df = pd.DataFrame(positions, columns=["frame_number", "id", "conf", "class", "x", "y", "w", "h", "r"])
df.to_csv(f"{video_path.split(".")[0]}_positions.csv", index=False)
df
# Out:
#         frame_number   id           conf     class            x            y  \
# 0                  1    1  small vehicle  0.802636  3148.414062  1927.137207
# 1                  1    2  small vehicle  0.795741  3054.048584   463.554932
# 2                  1    3  large vehicle  0.775441  3079.295166  1646.043091
# 3                  1    4  small vehicle  0.775234  3848.507080   297.390717
# 4                  1    5  small vehicle  0.774091   238.860870  1675.974121
# ...              ...  ...            ...       ...          ...          ...
# 682993          2787  257  small vehicle  0.010771  1617.497070   981.535706
# 682994          2787  258  small vehicle  0.010659  1522.585083   474.937256
# 682995          2787  259  small vehicle  0.010522  3660.509521  1577.630249
# 682996          2787  260  small vehicle  0.010248  3945.224609   213.176300
# 682997          2787  261  small vehicle  0.010177   268.325256  1421.742554
#
#                  w          h         r
# 0        64.585747  30.545033  0.689725
# 1        71.559853  32.174553  2.819362
# 2       190.205017  43.182365  0.649792
# 3        67.181137  28.472355  2.855587
# 4        68.550430  31.932125  0.058043
# ...            ...        ...       ...
# 682993   58.366802  25.187868  0.528911
# 682994   87.213348  34.550034  2.684876
# 682995   36.204979  23.738024  2.863581
# 682996   64.669098  28.852522  2.828396
# 682997   67.396378  27.681122  0.063268
#
# [682998 rows x 9 columns]

# %%
# Out:
# 291
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
