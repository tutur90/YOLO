# %%
import cv2
import numpy as np
from ultralytics import YOLO


from collections import defaultdict


# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# Load the YOLOv8 model
model = YOLO('yolov9c.pt')

# Open the video file
video_path = "DJI_0015.MOV"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])
# Store the class history
cls_history = defaultdict(lambda: [])

frame_number = 0

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        frame_number += 1
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        # detect only classes=[2,5,7], car, bus, truck
        results = model.track(frame, persist=True, conf=0.01, classes=[0])
        

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        # Get the boxes and track IDs
        
        if results[0].boxes.id is not None:
        
            boxes = results[0].boxes.xywh.cpu()
            clss = results[0].boxes.cls
            track_ids = results[0].boxes.id.int().cpu().tolist()


            # Plot the tracks
            for box, track_id, cls in zip(boxes, track_ids, clss):
                x, y, w, h = box
                track = track_history[track_id]
                ch = cls_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                ch.append((classNames[int(cls)], frame_number))
                # class name
                # print("Class name -->", classNames[int(cls)])

                # Draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(annotated_frame, [points], isClosed=False, color=(255, 255, 0), thickness=2)

        # Display the annotated frame
        cv2.imshow("YOLOv9 Tracking", cv2.resize(annotated_frame, (1920, 1080)))

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s-obb.pt to 'yolov8s-obb.pt'...
# 100%|██████████| 22.2M/22.2M [00:08<00:00, 2.64MB/s]
# 0: 544x1024 (no detections), 211.1ms
# Speed: 6.1ms preprocess, 211.1ms inference, 2.3ms postprocess per image at shape (1, 3, 544, 1024)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 52
#      49 annotated_frame = results[0].plot()
#      50 # Get the boxes and track IDs
# ---> 52 if results[0].boxes.id is not None:
#      54     boxes = results[0].boxes.xywh.cpu()
#      55     clss = results[0].boxes.cls
#
# AttributeError: 'NoneType' object has no attribute 'id'
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
import cv2
import numpy as np
from ultralytics import YOLO


from collections import defaultdict


# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# Load the YOLOv8 model
model = YOLO('yolov9c.pt')

# Open the video file
video_path = "Puente_guambra2.mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])
# Store the class history
cls_history = defaultdict(lambda: [])

frame_number = 0

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        frame_number += 1
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        # detect only classes=[2,5,7], car, bus, truck
        results = model.track(frame, persist=True, conf=0.002, classes=[2,5])
        

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        # Get the boxes and track IDs
        
        if results[0].boxes.id is not None:
        
            boxes = results[0].boxes.xywh.cpu()
            clss = results[0].boxes.cls
            track_ids = results[0].boxes.id.int().cpu().tolist()


            # Plot the tracks
            for box, track_id, cls in zip(boxes, track_ids, clss):
                x, y, w, h = box
                track = track_history[track_id]
                ch = cls_history[track_id]
                track.append((float(x), float(y)))  # x, y center point
                ch.append((classNames[int(cls)], frame_number))
                # class name
                # print("Class name -->", classNames[int(cls)])

                # Draw the tracking lines
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(annotated_frame, [points], isClosed=False, color=(255, 255, 0), thickness=2)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", cv2.resize(annotated_frame, (1920, 1080)))

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x640 68 cars, 3 buss, 315.6ms
# Speed: 2.1ms preprocess, 315.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 68 cars, 3 buss, 257.8ms
# Speed: 2.1ms preprocess, 257.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 68 cars, 3 buss, 249.9ms
# Speed: 2.4ms preprocess, 249.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 71 cars, 4 buss, 266.4ms
# Speed: 1.8ms preprocess, 266.4ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 61 cars, 3 buss, 252.8ms
# Speed: 2.1ms preprocess, 252.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 69 cars, 3 buss, 241.3ms
# Speed: 1.8ms preprocess, 241.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 61 cars, 2 buss, 230.3ms
# Speed: 1.8ms preprocess, 230.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 71 cars, 3 buss, 239.5ms
# Speed: 2.0ms preprocess, 239.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 73 cars, 3 buss, 241.5ms
# Speed: 2.3ms preprocess, 241.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 69 cars, 5 buss, 231.3ms
# Speed: 2.0ms preprocess, 231.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 73 cars,
8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 70 cars, 3 buss, 246.1ms
# Speed: 2.1ms preprocess, 246.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 78 cars, 3 buss, 243.9ms
# Speed: 1.8ms preprocess, 243.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 69 cars, 5 buss, 245.4ms
# Speed: 1.9ms preprocess, 245.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 72 cars, 2 buss, 236.4ms
# Speed: 1.7ms preprocess, 236.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 67 cars, 1 bus, 243.0ms
# Speed: 1.9ms preprocess, 243.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 65 cars, 3 buss, 245.5ms
# Speed: 1.9ms preprocess, 245.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 63 cars, 5 buss, 243.0ms
# Speed: 2.0ms preprocess, 243.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 62 cars, 5 buss, 244.5ms
# Speed: 2.2ms preprocess, 244.5ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 68 cars, 3 buss, 235.4ms
# Speed: 1.9ms preprocess, 235.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 66 cars, 2 buss, 236.1ms
# Speed: 2.3ms preprocess, 236.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 72 cars, 4 buss, 233.6ms
# Speed: 2.0ms preprocess, 233.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 72 cars, 2 buss, 248.5ms
# Speed: 1.9ms preprocess, 248.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 70 cars, 1 bus, 236.7ms
# Speed: 2.1ms preprocess, 236.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 65 cars, 1 bus, 249.8ms
# Speed: 2.4ms preprocess, 249.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 72 cars, 1 bus, 248.0ms
# Speed: 2.0ms preprocess, 248.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 66 cars, 2 buss, 246.1ms
# Speed: 1.9ms preprocess, 246.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 68 cars, 1 bus, 255.8ms
# Speed: 2.1ms preprocess, 255.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 67 cars, 1 bus, 234.2ms
# Speed: 2.2ms preprocess, 234.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 67 cars, 2 buss, 252.4ms
# Speed: 1.9ms preprocess, 252.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 70 cars, 2 buss, 245.0ms
# Speed: 1.9ms preprocess, 245.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 77 cars, 1 bus, 237.7ms
# Speed: 2.2ms preprocess, 237.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 76 cars, 2 buss, 245.8ms
# Speed: 2.0ms preprocess, 245.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 78 cars, 1 bus, 247.1ms
# Speed: 1.9ms preprocess, 247.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 82 cars, 2 buss, 248.4ms
# Speed: 2.2ms preprocess, 248.4ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 80 cars, 1 bus, 247.6ms
# Speed: 1.9ms preprocess, 247.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 80 cars, 2 buss, 247.7ms
# Speed: 2.0ms preprocess, 247.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 76 cars, 2 buss, 251.1ms
# Speed: 2.5ms preprocess, 251.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 71 cars, 2 buss, 263.6ms
# Speed: 2.2ms preprocess, 263.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 72 cars, 1 bus, 237.1ms
# Speed: 1.6ms preprocess, 237.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 74 cars, 2 buss, 233.7ms
# Speed: 2.0ms preprocess, 233.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 63 cars, 2 buss, 230.7ms
# Speed: 2.2ms preprocess, 230.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 66 cars, 1 bus, 238.7ms
# Speed: 2.0ms preprocess, 238.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 64 cars, 3 buss, 236.1ms
# Speed: 2.0ms preprocess, 236.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 66 cars, 2 buss, 238.5ms
# Speed: 2.1ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 78 cars, 3 buss, 257.3ms
# Speed: 9.0ms preprocess, 257.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 76 cars, 3 buss, 265.5ms
# Speed: 2.0ms preprocess, 265.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 45
#      42 frame_number += 1
#      43 # Run YOLOv8 tracking on the frame, persisting tracks between frames
#      44 # detect only classes=[2,5,7], car, bus, truck
# ---> 45 results = model.track(frame, persist=True, conf=0.002, classes=[2,5])
#      48 # Visualize the results on the frame
#      49 annotated_frame = results[0].plot()
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:492, in Model.track(self, source, stream, persist, **kwargs)
#     490 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     491 kwargs["mode"] = "track"
# --> 492 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/.local/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:597, in RepNCSPELAN4.forward(self, x)
#     595 y = list(self.cv1(x).chunk(2, 1))
#     596 y.extend((m(y[-1])) for m in [self.cv2, self.cv3])
# --> 597 return self.cv4(torch.cat(y, 1))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
